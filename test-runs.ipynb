# %%
import json
from gemini_test import extract_claims, custom_search_api, verify_claim

# %%
claims = extract_claims("The Eiffel Tower is an iconic lattice structure located in Paris, France. It was completed in 1889 and stands at a height of 300 meters. The tower was designed by Gustave Eiffel and has become a symbol of French culture and engineering.")

for claim in claims:
    print(f"\nClaim: {claim}")
    sources = custom_search_api(claim["claim"])
    if not sources:
        print("No sources found. Can not verify claim.")
        continue    
    result = verify_claim(claim["claim"], sources)
    print(json.dumps(result, indent=2))
# Out:
# [
#   {
#     "claim": "The Eiffel Tower is an iconic lattice structure.",
#     "original_text": "The Eiffel Tower is an iconic lattice structure"
#   },
#   {
#     "claim": "The Eiffel Tower is located in Paris, France.",
#     "original_text": "located in Paris, France."
#   },
#   {
#     "claim": "The Eiffel Tower was completed in 1889.",
#     "original_text": "It was completed in 1889"
#   },
#   {
#     "claim": "The Eiffel Tower stands at a height of 300 meters.",
#     "original_text": "stands at a height of 300 meters."
#   },
#   {
#     "claim": "The Eiffel Tower was designed by Gustave Eiffel.",
#     "original_text": "The tower was designed by Gustave Eiffel"
#   },
#   {
#     "claim": "The Eiffel Tower has become a symbol of French culture and engineering.",
#     "original_text": "has become a symbol of French culture and engineering."
#   }
# ]
#
# Claim: {'claim': 'The Eiffel Tower is an iconic lattice structure.', 'original_text': 'The Eiffel Tower is an iconic lattice structure'}
# [API Error] Request failed: 422 Client Error: Unprocessable Entity for url: https://laterical.com/api/call/
# No sources found. Can not verify claim.
#
# Claim: {'claim': 'The Eiffel Tower is located in Paris, France.', 'original_text': 'located in Paris, France.'}
# [API Error] Request failed: 422 Client Error: Unprocessable Entity for url: https://laterical.com/api/call/
# No sources found. Can not verify claim.
#
# Claim: {'claim': 'The Eiffel Tower was completed in 1889.', 'original_text': 'It was completed in 1889'}
# [API Error] Request failed: 422 Client Error: Unprocessable Entity for url: https://laterical.com/api/call/
# No sources found. Can not verify claim.
#
# Claim: {'claim': 'The Eiffel Tower stands at a height of 300 meters.', 'original_text': 'stands at a height of 300 meters.'}
# [API Error] Request failed: 422 Client Error: Unprocessable Entity for url: https://laterical.com/api/call/
# No sources found. Can not verify claim.
#
# Claim: {'claim': 'The Eiffel Tower was designed by Gustave Eiffel.', 'original_text': 'The tower was designed by Gustave Eiffel'}
# [API Error] Request failed: 422 Client Error: Unprocessable Entity for url: https://laterical.com/api/call/
# No sources found. Can not verify claim.
#
# Claim: {'claim': 'The Eiffel Tower has become a symbol of French culture and engineering.', 'original_text': 'has become a symbol of French culture and engineering.'}
# [API Error] Request failed: 422 Client Error: Unprocessable Entity for url: https://laterical.com/api/call/
# No sources found. Can not verify claim.

# %%
claims = extract_claims("Nepal is a part of India. It is a country with open access to sea. The capital city of Nepal is Kathmandu. It is know for its rich diversity and cultural heritage.")

for claim in claims:
    print(f"\nClaim: {claim}")
    sources = custom_search_api(claim["claim"])
    if not sources:
        print("No sources found. Can not verify claim.")
        continue    
    result = verify_claim(claim["claim"], sources)
    print(json.dumps(result, indent=2))
# Out:
# [
#   {
#     "claim": "Nepal is a part of India.",
#     "original_text": "Nepal is a part of India."
#   },
#   {
#     "claim": "Nepal is a country with open access to sea.",
#     "original_text": "It is a country with open access to sea."
#   },
#   {
#     "claim": "The capital city of Nepal is Kathmandu.",
#     "original_text": "The capital city of Nepal is Kathmandu."
#   },
#   {
#     "claim": "Nepal is known for its rich diversity and cultural heritage.",
#     "original_text": "It is know for its rich diversity and cultural heritage."
#   }
# ]
#
# Claim: {'claim': 'Nepal is a part of India.', 'original_text': 'Nepal is a part of India.'}
# {
#   "claim": "Nepal is a part of India.",
#   "assessment": "refuted",
#   "summary": "Nepal is a separate and sovereign country, not a part of India, and has never been under the control of any other nation or colonial power.",
#   "fixed_original_text": "Nepal is not a part of India.",
#   "confidence_score": 100,
#   "supporting_sources": [],
#   "refuting_sources": [
#     "https://en.wikipedia.org/wiki/Nepal",
#     "https://www.reddit.com/r/Nepal/comments/yt4c9z/what_is_with_some_indian_people_claiming_that/",
#     "https://www.quora.com/Was-Nepal-ever-a-part-of-India-If-so-why-is-there-no-mention-of-it-in-history",
#     "https://www.britannica.com/place/Nepal",
#     "https://homework.study.com/explanation/was-nepal-part-of-india-before-independence.html",
#     "https://history.stackexchange.com/questions/19274/why-did-nepal-and-bhutan-not-become-a-part-of-india-like-other-princely-states-w",
#     "https://twogetlost.com/is-nepal-in-india"
#   ]
# }
#
# Claim: {'claim': 'Nepal is a country with open access to sea.', 'original_text': 'It is a country with open access to sea.'}
# {
#   "claim": "Nepal is a country with open access to sea.",
#   "assessment": "refuted",
#   "summary": "Nepal is a landlocked country and does not have open access to the sea, requiring assistance from neighboring countries for seaport access.",
#   "fixed_original_text": "Nepal is a country without open access to sea.",
#   "confidence_score": 100,
#   "supporting_sources": [],
#   "refuting_sources": [
#     "https://www.reddit.com/r/Nepal/comments/zm0bwt/nepal_needs_sea_access_discuss/",
#     "https://en.wikipedia.org/wiki/Nepal",
#     "https://www.quora.com/Is-Nepal-landlocked",
#     "https://gjil.scholasticahq.com/post/335-the-indian-blockade-of-nepal-access-to-the-sea-and-freedom-of-transit-an-opportunity-to-vindicate-the-rights-of-landlocked-countries",
#     "https://maritimefairtrade.org/china-india-offers-seaport-access-to-landlocked-nepal/",
#     "https://journals.sagepub.com/doi/full/10.1177/21582440221087271",
#     "https://risingnepaldaily.com/news/60712",
#     "https://www.nationsencyclopedia.com/geography/Morocco-to-Slovakia/Nepal.html",
#     "https://papers.ssrn.com/sol3/papers.cfm?abstract_id=2707947",
#     "https://www.spotlightnepal.com/2017/11/27/landlocked-nepals-access-sea-significance-kosi-high-dam/"
#   ]
# }
#
# Claim: {'claim': 'The capital city of Nepal is Kathmandu.', 'original_text': 'The capital city of Nepal is Kathmandu.'}
# No sources found. Can not verify claim.
#
# Claim: {'claim': 'Nepal is known for its rich diversity and cultural heritage.', 'original_text': 'It is know for its rich diversity and cultural heritage.'}
# {
#   "claim": "Nepal is known for its rich diversity and cultural heritage.",
#   "assessment": "supported",
#   "summary": "Nepal is widely recognized for its rich cultural heritage and diverse traditions, encompassing various ethnic groups, customs, arts, and ancient practices.",
#   "fixed_original_text": null,
#   "confidence_score": 100,
#   "supporting_sources": [
#     "https://www.meer.com/en/86127-nepali-culture-diversity-traditions-and-heritage",
#     "https://asianheritagetreks.com/different-nepal/?srsltid=AfmBOorFfkwPBNRYOeAH_ITpyEryNfP7v4dUZSutKrd0rpNgkBgM7BcL",
#     "https://www.relaxgetaways.com/blog/cultural-facts-about-nepal?srsltid=AfmBOoqpO1302kHhImDrsLr56v56e_zCvBN7AamqeLt_kca1g1uNRjVc",
#     "https://www.gviusa.com/blog/smb-nepals-traditions-a-cultural-exploration/",
#     "https://ntb.gov.np/plan-your-trip/about-nepal/culture",
#     "https://vertexholiday.com/blogs/cultural-heritage-in-nepal",
#     "https://nepedup.com/2023/06/17/nepal-boasts-a-diverse-cultural-heritage/",
#     "https://www.icyenepal.org/welcome-to-nepal/",
#     "https://vocal.media/earth/nepal-land-of-diversity-and-natural-beauty",
#     "https://en.wikipedia.org/wiki/Culture_of_Nepal"
#   ],
#   "refuting_sources": []
# }
